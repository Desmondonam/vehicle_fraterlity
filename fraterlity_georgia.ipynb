# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 7.8 MB 47.9 MB/s
# ...
#      |████████████████████████████████| 16.6 MB 51.3 MB/s
# ...

# %%
#import the packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #if using matplotlib
import plotly.express as px #if using plotly
import geopandas as gpd

# %%
path = '/content/Counties_Georgia.shx'

# %%
file = '/content/Counties_Georgia.shx'

# %%
# !pip install fiona
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
data = gpd.read_file('/content/Counties_Georgia.shx')

# %%
data
# Out:
#                                               geometry
# 0    POLYGON ((-83.04293 30.94730, -83.04303 30.947...
# 1    POLYGON ((-81.40496 31.93701, -81.40499 31.937...
# 2    POLYGON ((-82.45869 31.83811, -82.43137 31.838...
# 3    POLYGON ((-83.61816 34.91143, -83.61795 34.911...
# 4    POLYGON ((-83.29782 32.54975, -83.29780 32.549...
# ..                                                 ...
# 154  POLYGON ((-83.66640 34.50360, -83.66625 34.503...
# 155  POLYGON ((-84.22751 33.18891, -84.23211 33.188...
# 156  POLYGON ((-83.84319 33.89478, -83.84177 33.895...
# 157  POLYGON ((-84.30275 32.99970, -84.29867 32.999...
# 158  POLYGON ((-83.81300 33.95315, -83.81301 33.953...
#
# [159 rows x 1 columns]

# %%
data.plot()

# %%
data.head()
# Out:
#                                             geometry
# 0  POLYGON ((-83.04293 30.94730, -83.04303 30.947...
# 1  POLYGON ((-81.40496 31.93701, -81.40499 31.937...
# 2  POLYGON ((-82.45869 31.83811, -82.43137 31.838...
# 3  POLYGON ((-83.61816 34.91143, -83.61795 34.911...
# 4  POLYGON ((-83.29782 32.54975, -83.29780 32.549...

# %%
data2 = df = pd.read_csv('/content/vehicle_fatality.csv')

# %%
data2.head()
# Out:
#         NAMELSAD10  Fatality_alcoh  Fatality_rate_alcoh  Fatality_bike  \
# 0   Appling County               3                16.21              0
# 1  Atkinson County               1                12.05              0
# 2     Bacon County               1                 8.94              0
# 3     Baker County               0                 0.00              0
# 4   Baldwin County               3                 6.69              1
#
#    Fatality_rate_bike  Fatality  Fatality_rate  Fatality_ped  \
# 0                0.00         5          27.02             1
# 1                0.00         3          36.16             0
# 2                0.00         3          26.82             1
# 3                0.00         0           0.00             0
# 4                2.23        11          24.54             2
#
#    Fatality_rate_ped  Fatality_speed  Fatality_rate_speed
# 0               5.40               0                 0.00
# ...

# %%
geometry = data['geometry']
geometry.head()
# Out:
# 0    POLYGON ((-83.04293 30.94730, -83.04303 30.947...
# 1    POLYGON ((-81.40496 31.93701, -81.40499 31.937...
# 2    POLYGON ((-82.45869 31.83811, -82.43137 31.838...
# 3    POLYGON ((-83.61816 34.91143, -83.61795 34.911...
# 4    POLYGON ((-83.29782 32.54975, -83.29780 32.549...
# Name: geometry, dtype: geometry

# %%
df = pd.DataFrame(data2)
df.head()
# Out:
#         NAMELSAD10  Fatality_alcoh  Fatality_rate_alcoh  Fatality_bike  \
# 0   Appling County               3                16.21              0
# 1  Atkinson County               1                12.05              0
# 2     Bacon County               1                 8.94              0
# 3     Baker County               0                 0.00              0
# 4   Baldwin County               3                 6.69              1
#
#    Fatality_rate_bike  Fatality  Fatality_rate  Fatality_ped  \
# 0                0.00         5          27.02             1
# 1                0.00         3          36.16             0
# 2                0.00         3          26.82             1
# 3                0.00         0           0.00             0
# 4                2.23        11          24.54             2
#
#    Fatality_rate_ped  Fatality_speed  Fatality_rate_speed
# 0               5.40               0                 0.00
# ...

# %%
geometry = pd.DataFrame(geometry)
geometry.head()
# Out:
#                                             geometry
# 0  POLYGON ((-83.04293 30.94730, -83.04303 30.947...
# 1  POLYGON ((-81.40496 31.93701, -81.40499 31.937...
# 2  POLYGON ((-82.45869 31.83811, -82.43137 31.838...
# 3  POLYGON ((-83.61816 34.91143, -83.61795 34.911...
# 4  POLYGON ((-83.29782 32.54975, -83.29780 32.549...

# %%
df['geometry'] = geometry

# %%
print(df)
# Out:
#            NAMELSAD10  Fatality_alcoh  Fatality_rate_alcoh  Fatality_bike  \
# 0      Appling County               3                16.21              0
# 1     Atkinson County               1                12.05              0
# 2        Bacon County               1                 8.94              0
# 3        Baker County               0                 0.00              0
# 4      Baldwin County               3                 6.69              1
# ..                ...             ...                  ...            ...
# 154  Whitfield County               2                 1.92              0
# 155     Wilcox County               0                 0.00              0
# 156     Wilkes County               0                 0.00              0
# 157  Wilkinson County               1                11.07              0
# 158      Worth County               1                 4.93              0
#
#      Fatality_rate_bike  Fatality  Fatality_rate  Fatality_ped  \
# ...

# %%
df.head()
# Out:
#         NAMELSAD10  Fatality_alcoh  Fatality_rate_alcoh  Fatality_bike  \
# 0   Appling County               3                16.21              0
# 1  Atkinson County               1                12.05              0
# 2     Bacon County               1                 8.94              0
# 3     Baker County               0                 0.00              0
# 4   Baldwin County               3                 6.69              1
#
#    Fatality_rate_bike  Fatality  Fatality_rate  Fatality_ped  \
# 0                0.00         5          27.02             1
# 1                0.00         3          36.16             0
# 2                0.00         3          26.82             1
# 3                0.00         0           0.00             0
# 4                2.23        11          24.54             2
#
#    Fatality_rate_ped  Fatality_speed  Fatality_rate_speed  \
# 0               5.40               0                 0.00
# ...

# %%
df.plot()

# %%
df.head()
# Out:
#         NAMELSAD10  Fatality_alcoh  Fatality_rate_alcoh  Fatality_bike  \
# 0   Appling County               3                16.21              0
# 1  Atkinson County               1                12.05              0
# 2     Bacon County               1                 8.94              0
# 3     Baker County               0                 0.00              0
# 4   Baldwin County               3                 6.69              1
#
#    Fatality_rate_bike  Fatality  Fatality_rate  Fatality_ped  \
# 0                0.00         5          27.02             1
# 1                0.00         3          36.16             0
# 2                0.00         3          26.82             1
# 3                0.00         0           0.00             0
# 4                2.23        11          24.54             2
#
#    Fatality_rate_ped  Fatality_speed  Fatality_rate_speed  \
# 0               5.40               0                 0.00
# ...

# %%
geometry = df['geometry']
geometry.head()
# Out:
# 0    POLYGON ((-83.04292768209446 30.94730185963084...
# 1    POLYGON ((-81.40496424778104 31.93700813655887...
# 2    POLYGON ((-82.45868555003965 31.83811008175156...
# 3    POLYGON ((-83.61815704274804 34.91143171027052...
# 4    POLYGON ((-83.29781982667 32.54975221204011, -...
# Name: geometry, dtype: object

# %%
geometry.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-586268c400be> in <module>
# ----> 1 geometry.plot()
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     284     def generate(self):
# ...

# %%
data = gpd.read_file(df['geometry'])
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-a3696e6c0d68> in <module>
# ----> 1 data = gpd.read_file(df['geometry'])
#       2 data
#
# /usr/local/lib/python3.8/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     257
#     258     if engine == "fiona":
# --> 259         return _read_file_fiona(
#     260             path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     261         )
#
# /usr/local/lib/python3.8/dist-packages/geopandas/io/file.py in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     301
#     302     with fiona_env():
# --> 303         with reader(path_or_bytes, **kwargs) as features:
#     304             crs = features.crs_wkt
#     305             # attempt to get EPSG code
#
# ...

# %%
data = gpd.read_file('/content/Counties_Georgia.shx')

# %%
data.plot()

# %%
df.head()
# Out:
#         NAMELSAD10  Fatality_alcoh  Fatality_rate_alcoh  Fatality_bike  \
# 0   Appling County               3                16.21              0
# 1  Atkinson County               1                12.05              0
# 2     Bacon County               1                 8.94              0
# 3     Baker County               0                 0.00              0
# 4   Baldwin County               3                 6.69              1
#
#    Fatality_rate_bike  Fatality  Fatality_rate  Fatality_ped  \
# 0                0.00         5          27.02             1
# 1                0.00         3          36.16             0
# 2                0.00         3          26.82             1
# 3                0.00         0           0.00             0
# 4                2.23        11          24.54             2
#
#    Fatality_rate_ped  Fatality_speed  Fatality_rate_speed  \
# 0               5.40               0                 0.00
# ...

# %%
data.plot()

# %%
data.head()
# Out:
#                                             geometry
# 0  POLYGON ((-83.04293 30.94730, -83.04303 30.947...
# 1  POLYGON ((-81.40496 31.93701, -81.40499 31.937...
# 2  POLYGON ((-82.45869 31.83811, -82.43137 31.838...
# 3  POLYGON ((-83.61816 34.91143, -83.61795 34.911...
# 4  POLYGON ((-83.29782 32.54975, -83.29780 32.549...

# %%
data2 = df = pd.read_csv('/content/vehicle_fatality.csv')

# %%
data2 = gpd.read_file('/content/vehicle_fatality.csv')

# %%
joined = data.geometry.append(data2.geometry)
joined.head()
# Out:
# 0    POLYGON ((-83.04293 30.94730, -83.04303 30.947...
# 1    POLYGON ((-81.40496 31.93701, -81.40499 31.937...
# 2    POLYGON ((-82.45869 31.83811, -82.43137 31.838...
# 3    POLYGON ((-83.61816 34.91143, -83.61795 34.911...
# 4    POLYGON ((-83.29782 32.54975, -83.29780 32.549...
# Name: geometry, dtype: geometry

# %%
joined.plot()

# %%
df = joined

# %%
df.plot()

# %%
df3 = data.append(data2)

# %%
data2.head()
# Out:
#         NAMELSAD10 Fatality_alcoh Fatality_rate_alcoh Fatality_bike  \
# 0   Appling County              3               16.21             0
# 1  Atkinson County              1               12.05             0
# 2     Bacon County              1                8.94             0
# 3     Baker County              0                 0.0             0
# 4   Baldwin County              3                6.69             1
#
#   Fatality_rate_bike Fatality Fatality_rate Fatality_ped Fatality_rate_ped  \
# 0                0.0        5         27.02            1               5.4
# 1                0.0        3         36.16            0               0.0
# 2                0.0        3         26.82            1              8.94
# 3                0.0        0           0.0            0               0.0
# 4               2.23       11         24.54            2              4.46
#
#   Fatality_speed Fatality_rate_speed geometry
# 0              0                 0.0     None
# ...

# %%
df3.plot()

# %%
df.plot()

# %%
import plotly.express as px

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
fig = px.choropleth(df,
                    color='Fatality_alcoh',
                    color_continuous_scale="Viridis_r", 
                    
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#         NAMELSAD10  Fatality_alcoh  Fatality_rate_alcoh  Fatality_bike  \
# 0   Appling County               3                16.21              0
# 1  Atkinson County               1                12.05              0
# 2     Bacon County               1                 8.94              0
# 3     Baker County               0                 0.00              0
# 4   Baldwin County               3                 6.69              1
#
#    Fatality_rate_bike  Fatality  Fatality_rate  Fatality_ped  \
# 0                0.00         5          27.02             1
# 1                0.00         3          36.16             0
# 2                0.00         3          26.82             1
# 3                0.00         0           0.00             0
# 4                2.23        11          24.54             2
#
#    Fatality_rate_ped  Fatality_speed  Fatality_rate_speed
# 0               5.40               0                 0.00
# ...

# %%
fig = px.choropleth(df,
                    color='NAMELSAD10',
                    color_continuous_scale="Viridis_r", 
                    
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(df,
                    color='Fatality_rate',
                    color_continuous_scale="GnBu", 
)
                    
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(df['Fatality_alcoh'])                    
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data2.head()
# Out:
#         NAMELSAD10 Fatality_alcoh Fatality_rate_alcoh Fatality_bike  \
# 0   Appling County              3               16.21             0
# 1  Atkinson County              1               12.05             0
# 2     Bacon County              1                8.94             0
# 3     Baker County              0                 0.0             0
# 4   Baldwin County              3                6.69             1
#
#   Fatality_rate_bike Fatality Fatality_rate Fatality_ped Fatality_rate_ped  \
# 0                0.0        5         27.02            1               5.4
# 1                0.0        3         36.16            0               0.0
# 2                0.0        3         26.82            1              8.94
# 3                0.0        0           0.0            0               0.0
# 4               2.23       11         24.54            2              4.46
#
#   Fatality_speed Fatality_rate_speed geometry
# 0              0                 0.0     None
# ...

# %%
geometry.head()
# Out:
# 0    POLYGON ((-83.04292768209446 30.94730185963084...
# 1    POLYGON ((-81.40496424778104 31.93700813655887...
# 2    POLYGON ((-82.45868555003965 31.83811008175156...
# 3    POLYGON ((-83.61815704274804 34.91143171027052...
# 4    POLYGON ((-83.29781982667 32.54975221204011, -...
# Name: geometry, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-71acbb522f25> in <module>
# ----> 1 data2.join(geometry)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# ...
